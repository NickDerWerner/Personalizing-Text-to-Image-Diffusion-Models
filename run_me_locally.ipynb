# %% [markdown]
# # Local Execution Notebook
#
# This notebook allows you to run the project locally, mirroring the functionality of `run_me_in_collab.ipynb` but adapted for a local environment.

# %%
# Install dependencies
# You might want to run this once or ensure your environment is set up correctly.
# !pip install -r requirements.txt
# !pip install diffusers transformers accelerate tqdm
# Out:
# Requirement already satisfied: diffusers in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (0.35.2)
# Requirement already satisfied: transformers in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (4.57.3)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: torch in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (2.9.1)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (0.24.1)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (0.42.0)
# Requirement already satisfied: importlib_metadata in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (0.36.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (2.3.5)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (2025.11.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.13/site-packages (from diffusers->-r requirements.txt (line 1)) (12.0.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from transformers->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.13/site-packages (from transformers->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in ./.venv/lib/python3.13/site-packages (from transformers->-r requirements.txt (line 2)) (0.22.1)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.13/site-packages (from transformers->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.34.0->diffusers->-r requirements.txt (line 1)) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.34.0->diffusers->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.34.0->diffusers->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.13/site-packages (from accelerate->-r requirements.txt (line 3)) (7.1.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.13/site-packages (from torch->-r requirements.txt (line 4)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.13/site-packages (from torch->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.13/site-packages (from torch->-r requirements.txt (line 4)) (3.6)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.13/site-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: scipy in ./.venv/lib/python3.13/site-packages (from bitsandbytes->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.13/site-packages (from importlib_metadata->diffusers->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->diffusers->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->diffusers->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->diffusers->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->diffusers->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: diffusers in ./.venv/lib/python3.13/site-packages (0.35.2)
# Requirement already satisfied: transformers in ./.venv/lib/python3.13/site-packages (4.57.3)
# Requirement already satisfied: accelerate in ./.venv/lib/python3.13/site-packages (1.12.0)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: importlib_metadata in ./.venv/lib/python3.13/site-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.13/site-packages (from diffusers) (3.20.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in ./.venv/lib/python3.13/site-packages (from diffusers) (0.36.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (from diffusers) (2.3.5)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.13/site-packages (from diffusers) (2025.11.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from diffusers) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in ./.venv/lib/python3.13/site-packages (from diffusers) (0.7.0)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.13/site-packages (from diffusers) (12.0.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in ./.venv/lib/python3.13/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.34.0->diffusers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.34.0->diffusers) (1.2.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.13/site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: torch>=2.0.0 in ./.venv/lib/python3.13/site-packages (from accelerate) (2.9.1)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.6)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.13/site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->diffusers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->diffusers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->diffusers) (2025.11.12)

# %%
import os
import sys

# 1. Setup Paths
# Ensure the current directory is in python path
REPO_DIR = os.getcwd()
if REPO_DIR not in sys.path:
    sys.path.append(REPO_DIR)

# 2. Define settings
MODEL_NAME = "runwayml/stable-diffusion-v1-5"
CLASS_PROMPT = "A photo of a man"
NEGATIVE_PROMPT = "oversaturated, painted, old, high contrast, cartoon, 3d, 3d render, cgi, neon, art, vibrant, digital art, painting, drawing, sketch, black and white, monochrome, sepia, vintage"
BATCH_SIZE = 2
# Number of images to generate
NUM_IMAGES = 2 

# Local output directory (created inside the repo folder)
OUTPUT_DIR = os.path.join(REPO_DIR, "experiments", "NickExperiments")

# Create the folder if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"🚀 Starting generation of {NUM_IMAGES} image(s)...")
print(f"📂 Saving to: {OUTPUT_DIR}")
# Out:
# 🚀 Starting generation of 2 image(s)...
# 📂 Saving to: /Users/nickwerner/Documents/Projects/Personalizing-Text-to-Image-Diffusion-Models/experiments/NickExperiments

# %%
# 3. Run the script
# We call the python script directly using the settings defined above.
# !python src/generate_class_images.py \
  --model_id "{MODEL_NAME}" \
  --prompt "{CLASS_PROMPT}" \
  --negative_prompt "{NEGATIVE_PROMPT}" \
  --num_images {NUM_IMAGES} \
  --output_dir "{OUTPUT_DIR}" \
  --batch_size {BATCH_SIZE}
# Out:
# /Users/nickwerner/Documents/Projects/Personalizing-Text-to-Image-Diffusion-Models/.venv/lib/python3.13/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# Using device: mps
# Loading model: runwayml/stable-diffusion-v1-5...
# Loading pipeline components...:   0%|                     | 0/6 [00:00<?, ?it/s]`torch_dtype` is deprecated! Use `dtype` instead!
# Loading pipeline components...: 100%|█████████████| 6/6 [00:00<00:00, 23.76it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Generating 2 images for class prompt: 'A photo of a man'
# Generating 2 images starting from ID 0 in batches of 2...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
#   0%|                                                    | 0/50 [00:00<?, ?it/s]
#   2%|▉                                           | 1/50 [00:02<01:52,  2.30s/it]
#   4%|█▊                                          | 2/50 [00:03<01:11,  1.50s/it]
#   6%|██▋                                         | 3/50 [00:04<00:58,  1.24s/it]
#   8%|███▌                                        | 4/50 [00:05<00:51,  1.12s/it]
#  10%|████▍                                       | 5/50 [00:06<00:47,  1.06s/it]
#  12%|█████▎                                      | 6/50 [00:07<00:44,  1.02s/it]
#  14%|██████▏                                     | 7/50 [00:07<00:42,  1.00it/s]
#  16%|███████                                     | 8/50 [00:08<00:41,  1.02it/s]
#  18%|███████▉                                    | 9/50 [00:09<00:39,  1.03it/s]
#  20%|████████▌                                  | 10/50 [00:10<00:38,  1.04it/s]
#  22%|█████████▍                                 | 11/50 [00:11<00:37,  1.04it/s]
#  24%|██████████▎                                | 12/50 [00:12<00:36,  1.05it/s]
#  26%|███████████▏                               | 13/50 [00:13<00:35,  1.05it/s]
#  28%|████████████                               | 14/50 [00:14<00:34,  1.05it/s]
#  30%|████████████▉                              | 15/50 [00:15<00:33,  1.06it/s]
#  32%|█████████████▊                             | 16/50 [00:16<00:32,  1.06it/s]
#  34%|██████████████▌                            | 17/50 [00:17<00:31,  1.06it/s]
#  36%|███████████████▍                           | 18/50 [00:18<00:30,  1.06it/s]
#  38%|████████████████▎                          | 19/50 [00:19<00:29,  1.06it/s]
#  40%|█████████████████▏                         | 20/50 [00:20<00:28,  1.07it/s]
#  42%|██████████████████                         | 21/50 [00:21<00:27,  1.07it/s]
#  44%|██████████████████▉                        | 22/50 [00:22<00:26,  1.07it/s]
#  46%|███████████████████▊                       | 23/50 [00:23<00:25,  1.07it/s]
#  48%|████████████████████▋                      | 24/50 [00:23<00:24,  1.07it/s]
#  50%|█████████████████████▌                     | 25/50 [00:24<00:23,  1.07it/s]
#  52%|██████████████████████▎                    | 26/50 [00:25<00:22,  1.07it/s]
#  54%|███████████████████████▏                   | 27/50 [00:26<00:21,  1.07it/s]
#  56%|████████████████████████                   | 28/50 [00:27<00:20,  1.07it/s]
#  58%|████████████████████████▉                  | 29/50 [00:28<00:19,  1.07it/s]
#  60%|█████████████████████████▊                 | 30/50 [00:29<00:18,  1.07it/s]
#  62%|██████████████████████████▋                | 31/50 [00:30<00:17,  1.07it/s]
#  64%|███████████████████████████▌               | 32/50 [00:31<00:16,  1.07it/s]
#  66%|████████████████████████████▍              | 33/50 [00:32<00:15,  1.07it/s]
#  68%|█████████████████████████████▏             | 34/50 [00:33<00:15,  1.07it/s]
#  70%|██████████████████████████████             | 35/50 [00:34<00:14,  1.06it/s]
#  72%|██████████████████████████████▉            | 36/50 [00:35<00:13,  1.06it/s]
#  74%|███████████████████████████████▊           | 37/50 [00:36<00:12,  1.06it/s]
#  76%|████████████████████████████████▋          | 38/50 [00:37<00:11,  1.06it/s]
#  78%|█████████████████████████████████▌         | 39/50 [00:38<00:10,  1.06it/s]
#  80%|██████████████████████████████████▍        | 40/50 [00:39<00:09,  1.05it/s]
#  82%|███████████████████████████████████▎       | 41/50 [00:39<00:08,  1.05it/s]
#  84%|████████████████████████████████████       | 42/50 [00:40<00:07,  1.05it/s]
#  86%|████████████████████████████████████▉      | 43/50 [00:41<00:06,  1.05it/s]
#  88%|█████████████████████████████████████▊     | 44/50 [00:42<00:05,  1.05it/s]
#  90%|██████████████████████████████████████▋    | 45/50 [00:43<00:04,  1.05it/s]
#  92%|███████████████████████████████████████▌   | 46/50 [00:44<00:03,  1.05it/s]
#  94%|████████████████████████████████████████▍  | 47/50 [00:45<00:02,  1.05it/s]
#  96%|█████████████████████████████████████████▎ | 48/50 [00:46<00:01,  1.05it/s]
#  98%|██████████████████████████████████████████▏| 49/50 [00:47<00:00,  1.06it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:48<00:00,  1.03it/s]
# 100%|█████████████████████████████████████████████| 1/1 [00:49<00:00, 49.72s/it]
# Generation complete.

# %%
# 4. Check and Display Results
import os
from IPython.display import Image, display

print(f"📂 Checking content of: {OUTPUT_DIR}")

if os.path.exists(OUTPUT_DIR):
    # Filter for image files
    files = sorted([f for f in os.listdir(OUTPUT_DIR) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
    print(f"📄 Found files: {files}")

    if len(files) > 0:
        # Display the first image found
        image_path = os.path.join(OUTPUT_DIR, files[0])
        print(f"🖼️ Displaying: {files[0]}")
        display(Image(filename=image_path, width=256))
    else:
        print("❌ Folder exists but contains no images.")
else:
    print("❌ Folder path does not exist.")
# Out:
# 📂 Checking content of: /Users/nickwerner/Documents/Projects/Personalizing-Text-to-Image-Diffusion-Models/experiments/NickExperiments
# 📄 Found files: []
# ❌ Folder exists but contains no images.
