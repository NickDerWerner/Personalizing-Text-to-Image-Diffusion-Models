# %% [markdown]
# # DreamBooth Training Setup
#
# ## 1. Mount Google Drive
# This is required to store your model checkpoints and data persistently.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Install Dependencies
# Install the required libraries from requirements.txt (if uploaded) or directly.

# %%
# !pip install diffusers transformers accelerate torch torchvision bitsandbytes

# %% [markdown]
# ## 3. Check GPU
# Ensure you are using a GPU runtime.

# %%
# !nvidia-smi
