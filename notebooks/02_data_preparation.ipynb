# %% [markdown]
# # Phase 2: Data Preparation
#
# This notebook handles the creation of the dataset for DreamBooth training.
#
# ## 1. Setup Environment

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Neural\ Networks/dreambooth-implementation
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Generate Class Images (Regularization)
# We generate 200 images of the generic class (e.g., "a cat") to prevent the model from forgetting what a generic cat looks like (Prior Preservation).

# %%
# !python src/generate_class_images.py --model_id "runwayml/stable-diffusion-v1-5" --prompt "a cat" --num_images 200 --output_dir "dataset/class_images"

# %% [markdown]
# ## 3. Prepare Instance Images
# Upload your 3-5 subject images to a folder (e.g., `raw_images`) in your Drive project folder, then run this cell to resize them.

# %%
# Example usage: assuming you uploaded images to 'raw_images'
# !mkdir -p raw_images
# !python src/resize_images.py --input_dir "raw_images" --output_dir "dataset/instance_images" --size 512
